# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
t = sns.load_dataset("titanic")

# %%
s = sns.load_dataset("flights")

# %%
p = sns.load_dataset("tips")

# %%
plt.figure(figsize=(25,5))

plt.subplot(1,3,1)
sns.barplot(data=t,x="class",y="survived",hue="sex")


plt.subplot(1,3,2)
sns.boxplot(data=s ,x="year",y="passengers")

x=[1,2,3]
y=[5,6,7]
plt.subplot(1,3,3)
sns.lineplot(x,y)
# Out:
# /Users/ayush/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# Out:
#   File "/var/folders/cx/z1bf65993t54gnc61p3lhfnr0000gn/T/ipykernel_37842/939966892.py", line 1
#     plt.?
#         ^
# SyntaxError: invalid syntax
